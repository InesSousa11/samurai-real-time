# %%
# %cd /content
# !rm -rf samurai-real-time
# !git clone https://github.com/InesSousa11/samurai-real-time.git
# %cd samurai-real-time

# %%
# !pip install -U pip wheel
# !pip install -e .
# !pip install "gradio>=4.0.0" ultralytics opencv-python

# %%
# %cd /content/samurai-real-time/checkpoints
# !chmod +x download_ckpts.sh
# !./download_ckpts.sh
# !ls -lh

# %%
# %cd /content/samurai-real-time
# !python demo/demo_colab_vid_scores.py
